# %% [markdown]
# # Installation

# %%
# !pip install git+https://github.com/dnth/rag-datakit.git

# %% [markdown]
# # Datset Loading and Preprocessing

# %%
from datasets import load_dataset, concatenate_datasets

# Load each split separately
easy_para = load_dataset("frankwong2001/ssf-dataset_Full_synthetic_v2", "easy_triplets_paraphrase")["train"]
hard_para = load_dataset("frankwong2001/ssf-dataset_Full_synthetic_v2", "hard_triplets_paraphrase")["train"]

# Concatenate all splits into one dataset
dataset = concatenate_datasets([easy_para, hard_para])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# easy_triplets_paraphrase/train-00000-of-(…):   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1885 [00:00<?, ? examples/s]
# hard_triplets_paraphrase/train-00000-of-(…):   0%|          | 0.00/5.16M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1885 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['Sector', 'Track', 'Job Role', 'anchor', 'Performance Expectation', 'positive', 'negative', 'distilabel_metadata', 'model_name'],
#     num_rows: 3770
# })

# %%
dataset = dataset.select_columns(['anchor', 'positive', 'negative'])
dataset
# Out:
# Dataset({
#     features: ['anchor', 'positive', 'negative'],
#     num_rows: 3770
# })

# %% [markdown]
# # Data Preparation and Shuffling

# %%
dataset = dataset.shuffle()
dataset
# Out:
# Dataset({
#     features: ['anchor', 'positive', 'negative'],
#     num_rows: 3770
# })

# %%
train_size = int(0.8 * len(dataset))
valid_size = len(dataset) - train_size

train_dataset = dataset.select(range(train_size))
valid_dataset = dataset.select(range(train_size, train_size + valid_size))

# %%
print("Train Set\n", train_dataset)
print("Valid Set\n", valid_dataset)
# Out:
# Train Set
#  Dataset({
#     features: ['anchor', 'positive', 'negative'],
#     num_rows: 3016
# })
# Valid Set
#  Dataset({
#     features: ['anchor', 'positive', 'negative'],
#     num_rows: 754
# })

# %% [markdown]
# # Publish Final Dataset

# %%
from datasets import DatasetDict

ds = DatasetDict({
    "train": train_dataset,
    "valid": valid_dataset
})

ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['anchor', 'positive', 'negative'],
#         num_rows: 3016
#     })
#     valid: Dataset({
#         features: ['anchor', 'positive', 'negative'],
#         num_rows: 754
#     })
# })

# %%
ds.push_to_hub("frankwong2001/ssf-train-valid-full-synthetic-v2")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#                                         :  14%|#3        |  526kB / 3.88MB
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#                                         :  53%|#####3    |  525kB /  985kB
# CommitInfo(commit_url='https://huggingface.co/datasets/frankwong2001/ssf-train-valid-full-synthetic-v2/commit/dc8851d3b29c0127f1c2d521e73a8d34a91aa520', commit_message='Upload dataset', commit_description='', oid='dc8851d3b29c0127f1c2d521e73a8d34a91aa520', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/frankwong2001/ssf-train-valid-full-synthetic-v2', endpoint='https://huggingface.co', repo_type='dataset', repo_id='frankwong2001/ssf-train-valid-full-synthetic-v2'), pr_revision=None, pr_num=None)
